# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.ticker import MultipleLocator
import math
fig, ax = plt.subplots()


t = np.array([1.652, 2.092, 1.789])
l = np.array([0.25, 0.96, 0.7])
r = np.array([0.028, 0.0091, 1.789])
v = np.array([30, 60, 45])
v = np.radians(v)
v = np.sin(v)


y1 = t / np.sqrt(l)
x1 = r / l
x2 = np.log(x1)
y2 = np.log(y1)
plt.scatter(x2, y2, label="Logarimeterade mätärden", color="black")


const = np.polyfit(x2, y2, 1)
print(const)

x = np.arange(-6, 3, 0.1)
y = const[0]*x + const[1]

ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_minor_locator(MultipleLocator(1))
plt.xlim(-6, 3)
plt.ylim(-3, 3)


plt.plot(x, y, label="y = {:.3f}x + {:.3f}".format(const[0], const[1]))
plt.legend()
plt.xlabel(r"$\ln\left(\dfrac{r}{l}\right)$ []")
plt.ylabel(r"$\ln\left(\dfrac{t}{\sqrt{l}}\right)$ $[TL^{-\frac{1}{2}}]$")
plt.show
# Out:
# [-0.00581713  0.89309429]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.ticker import MultipleLocator
import math
fig, ax = plt.subplots()


t = np.array([1.620, 2.913, 1.943])
l = np.array([1, 1, 1])
r = np.array([0.028, 0.0091, 1.789])
v = np.array([0.08, 0.028, 0.060])



y1 = t / np.sqrt(l)
x1 = v
x2 = np.log(x1)
y2 = np.log(y1)
plt.scatter(x2, y2, label="Logarimeterade mätärden", color="black")


const = np.polyfit(x2, y2, 1)
print(const)
x = np.arange(-6, 4, 0.1)
y = const[0]*x + const[1]

ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_minor_locator(MultipleLocator(1))
plt.xlim(-6, 3)
plt.ylim(-3, 3)


plt.plot(x, y, label="y = {:.3f}x + {:.3f}".format(const[0], const[1]))
plt.legend()
plt.xlabel(r"$\ln\left(\sin\theta\right)$ []")
plt.ylabel(r"$\ln\left(\dfrac{t}{\sqrt{l}}\right)$ $[TL^{-\frac{1}{2}}]$")
plt.show
# Out:
# [-0.55326354 -0.90544342]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.ticker import MultipleLocator
import math
fig, ax = plt.subplots()


t = np.array([1.620, 2.913, 1.943])
l = np.array([0.96, 0.96, 0.96])
r = np.array([0.028, 0.0091, 1.789])
v = np.array([0.11, 0.035, 0.075])



y1 = t / np.sqrt(l)
x1 = v
x2 = np.log(x1)
y2 = np.log(y1)
plt.scatter(x2, y2, label="Logarimeterade mätvärden", color="black")


const = np.polyfit(x2, y2, 1)
print(const)
x = np.arange(-5.1, 1.1, 0.1)
y = const[0]*x + const[1]

ax.xaxis.set_minor_locator(MultipleLocator(0.5))
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_minor_locator(MultipleLocator(0.5))
plt.xlim(-4, -1)
plt.ylim(-1, 3)


plt.plot(x, y, label="y = {:.3f}x + {:.3f}".format(const[0], const[1]))
plt.legend()
plt.xlabel(r"$\ln\left(\sin\theta\right)$", fontsize=14)
#plt.ylabel(r"$\ln\left(\dfrac{t}{\sqrt{l}}\dfrac{1m^{\dfrac{-1}{2}}{1s}\right)$", fontsize=14)
#plt.ylabel(r"$\ln\left(\dfrac{t}{\sqrt{l}}\dfrac{1\text{m}^{-\frac{1}{2}}}{1\text{s}}\right)$", fontsize=14)
plt.ylabel(r"$\ln\left(\dfrac{t}{\sqrt{l}}\dfrac{1 \, \text{m}^{\frac{1}{2}}}{1 \, \text{s}}\right)$", fontsize=14)



plt.show
# Out:
# [-0.51507701 -0.64025858]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.ticker import MultipleLocator
import math
fig, ax = plt.subplots()


t = np.array([1.652, 2.092, 1.789])
l = np.array([0.61, 0.96, 0.7])
r = np.array([0.028, 0.0182, 0.21])
v = np.array([30, 60, 45])
v = np.radians(v)
v = np.sin(v)


y1 = t / np.sqrt(l)
x1 = r / l
x2 = np.log(x1)
y2 = np.log(y1)
plt.scatter(x2, y2, label="Logarimeterade mätvärden", color="black")


const = np.polyfit(x2, y2, 1)
print(const)

x = np.arange(-6, 3, 0.1)
y = const[0]*x + const[1]

ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_minor_locator(MultipleLocator(1))
plt.xlim(-6, 3)
plt.ylim(-3, 3)


plt.plot(x, y, label="y = {:.3f}x + {:.3f}".format(const[0], const[1]))
plt.legend()
plt.xlabel(r"$\ln\left(\dfrac{r}{l}\right)$", fontsize=14)
#plt.ylabel(r"$\ln\left(\dfrac{t}{\sqrt{l}}\right)$ $[TL^{-\frac{1}{2}}]$", fontsize=14)
#plt.ylabel(r"$\ln\left(\dfrac{t}{\sqrt{l}}\dfrac{1\text{m}^{-\frac{1}{2}}}{1\text{s}}\right)$", fontsize=14)
plt.ylabel(r"$\ln\left(\dfrac{t}{\sqrt{l}}\dfrac{1 \, \text{m}^{\frac{1}{2}}}{1 \, \text{s}}\right)$", fontsize=14)

plt.show
# Out:
# [0.00135067 0.75960157]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots()


t = np.array([0.14, 0.23, 0.15, 0.298])
r = np.array([0.68, 0.838, 0.647, 0.94])



y1 = t
x1 = r
x2 = np.log(x1)
y2 = np.log(y1)
plt.scatter(x2, y2, label="Logarimeterade mätvärden", color="black")


const = np.polyfit(x2, y2, 1)
print(const)

x = np.arange(-3.1, 2.1, 0.1)
y = const[0]*x + const[1]

ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_minor_locator(MultipleLocator(1))
plt.xlim(-2, 1)
plt.ylim(-3, 0)

plt.plot(x, y, label="y = {:.3f}x + {:.3f}".format(const[0], const[1]))
plt.legend()
plt.xlabel(r"$\ln\left(\dfrac{r_1}{R}\right)$", fontsize=14)
plt.ylabel(r"$\ln\left(\dfrac{\Delta t}{1 \, \text{s}}\right)$", fontsize=14)

plt.show
# Out:
# [ 2.00117818 -1.1057385 ]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots()


r = np.array([0.415, 1.282, 1.193])
t = np.array([1.658, 1.658, 1.65])



y1 = t
x1 = r
x2 = np.log(x1)
y2 = np.log(y1)
plt.scatter(x2, y2, label="Logarimeterade mätvärden", color="black")


const = np.polyfit(x2, y2, 1)
print(const)

x = np.arange(-3.1, 2.1, 0.1)
y = const[0]*x + const[1]

ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_minor_locator(MultipleLocator(1))
plt.xlim(-2, 2)
plt.ylim(-1, 2)

plt.plot(x, y, label="y = {:.3f}x + {:.3f}".format(const[0], const[1]))
plt.legend()
plt.xlabel(r"$\ln\left(\dfrac{m}{1 \, \text{kg}}\right)$", fontsize=14)
plt.ylabel(r"$\ln\left(\dfrac{t}{1 \, \text{s}}\right)$", fontsize=14)

plt.show
# Out:
# [-0.00198941  0.50369835]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots()


t = np.array([1.356, 2.266, 2.712, 2.05])
l = np.array([0.445, 1.173, 1.730, 1])



y1 = t
x1 = l
x2 = np.log(x1)
y2 = np.log(y1)
plt.scatter(x2, y2, label="Logarimeterade mätvärden", color="black")


const = np.polyfit(x2, y2, 1)
print(const)

x = np.arange(-3.1, 2.1, 0.1)
y = const[0]*x + const[1]

ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_minor_locator(MultipleLocator(1))
plt.xlim(-2, 1)
plt.ylim(-1, 2)

plt.plot(x, y, label="y = {:.3f}x + {:.3f}".format(const[0], const[1]))
plt.legend()
plt.xlabel(r"$\ln\left(\dfrac{l}{1 \, \text{m}}\right)$", fontsize=14)
plt.ylabel(r"$\ln\left(\dfrac{t}{1 \, \text{s}}\right)$", fontsize=14)
#plt.ylabel(r"$\ln\left(t\right)$ $[T]$", fontsize=14)

plt.show
# Out:
# [0.51402352 0.72262734]
# <function matplotlib.pyplot.show(close=None, block=None)>
